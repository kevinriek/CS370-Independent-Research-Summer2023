# %%
import numpy as np
import math 
import queue
import os
import neat
import visualize
import random
import matplotlib.pyplot as plt
import pickle

# %load_ext autoreload
# %autoreload 2

import GameManager
from GameManager import *

import Neat_AI
from Neat_AI import *

import AI_modules
from AI_modules import *

import my_reporters
from my_reporters import *

# %%
local_dir = os.path.abspath('')
config_path = os.path.join(local_dir, 'config-feedforward')

# %%
dimensions = (15,15)
units_per_side = 3
manager = GameManager.map_manager(dimensions)

# for i in range(games_run):
#also resets map
manager.setup_layouts_rand(1, units_per_side)
manager.apply_map_layout(0)

#unit1 = manager.Units[4]
unit2 = manager.Units[2]

e_unit1 = manager.Units[4]
manager.move_unit(unit2, (5, 6))
#manager.move_unit(unit1, (6, 4))
manager.move_unit(e_unit1, (5, 7))
manager.find_movement(unit2)
manager.move_unit(unit2, (5, 7))

# manager.find_movement(e_unit1)
# manager.move_unit(e_unit1, (5, 6))
print(manager)

for tile in manager.visited_tiles:
   print(tile.pos)

print(unit2)
print(e_unit1)
# Out:
# here
# here
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ]
# [c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][I][ ][ ][ ][ ][ ][ ][ ]
# [ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# (5, 7)
# (6, 7)
# (5, 8)
# (4, 7)
# (5, 6)
# (6, 8)
# (5, 9)
# (4, 8)
# (3, 7)
# (4, 6)
# Unit:
# 	pos: (5, 6)
# 	curr_move: -inf
# 	hp: 0
# 	temp_hp: 0
# 	Type: archer
# 	max_move: 2
# 	Att: 20
# 	Def: 5
# 	Team: 0
# 	rotation: 1
#
# Unit:
# 	pos: (5, 7)
# 	curr_move: -inf
# 	hp: 68.75
# 	temp_hp: 68.75
# 	Type: infantry
# 	max_move: 2
# 	Att: 20
# 	Def: 10
# 	Team: 1
# 	rotation: 2

# %%
dimensions = (15,15)
units_per_side = 12
manager = GameManager.map_manager(dimensions)

# for i in range(games_run):
#also resets map
manager.setup_layouts_rand(1, units_per_side)
manager.apply_map_layout(0)
print(manager)

while (manager.game_joever() == -1 and manager.turn_count < 8): #Turn Count limit may have to be modified
    for unit in manager.Teams[manager.curr_team].live_units:
        win_move = (0, 0)
        if manager.curr_team == 0:
            #win_move = neat_ai(manager, unit, best_networks[1])
            win_move = script_ai(manager, unit)
        elif manager.curr_team == 1:
            win_move = script_ai(manager, unit)
            #win_move = neat_ai(manager, unit, win_net)
        manager.move_unit(unit, win_move)
    print(manager)
    manager.Turn()
# Out:
# [c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ]
# [ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ]
# [ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ]
# [ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][I][ ]
# [ ][ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][I]
# [ ][ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ]
# [a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ]
# [ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ]
#
# [ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ]
# [ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ]
# [ ][ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ]
# [ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][I][ ]
# [ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][I]
# [ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ]
# [ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][C][ ]
# [ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][C][ ]
#
# [ ][ ][c][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ]
# [ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][a][ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][a][ ][ ][ ][ ][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][ ][ ][ ][i][ ][ ][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][i][ ][ ][ ][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][ ][ ][ ][i][ ][ ][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][A][A][ ][ ]
# [ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ]
# [ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][C][ ][ ]
# [ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][c][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ]
# [ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][a][ ][ ][a][ ][ ][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][ ][ ][ ][ ][ ][i][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ][I][ ][ ]
# [ ][ ][ ][ ][ ][ ][i][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][ ][ ][a][ ][ ][ ][ ][ ][ ][A][A][ ][ ]
# [ ][ ][ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][C][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][C][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][c][ ][ ][C][C][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][a][ ][ ][a][ ][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][i][ ][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][i][ ][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][i][ ][ ][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][i][ ][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][a][ ][ ][ ][ ][A][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][C][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][C][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][c][ ][C][C][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][a][a][i][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][i][ ][ ][ ][I][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][c][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][c][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][a][a][ ][C][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][I][I][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][i][ ][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][c][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][a][ ][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][I][I][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][c][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][a][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][C][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][I][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][c][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][i][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][i][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][A][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][ ][ ][A][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][C][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
#
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][c][a][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][c][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][a][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]

# %%
print(GameManager_Copy.Tile.Terrain)
# Out:
# <class 'GameManager_Copy.Tile.Terrain'>
